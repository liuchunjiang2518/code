# %%
# 序列：内容连续有序，可以使用下标索引(index)的一类容器
# 切片：从序列切出子序列：列表元组字符串
# 序列[起始下标:结束下标:步长]
li=[1,2,3,4,5,6]
li[1:4]
tu=(0,1,2,3,4,5,6)
tu[0::2]
for i in li[1::2]:
    print(i)
li[4:0:-1]
li[::-1]
li[::-2]
# Out:
# 2
# 4
# 6
# [6, 4, 2]

# %%
str_ = '我就部已 宏春万是我 不是 非也'
str_new = str_[9:4:-1]
str_new
str_1 = str_.replace('已 ','###')
str_2 = str_1.replace(' 不','###')
print((str_2.split('###'))[1][::-1])
# Out:
# 我是万春宏
