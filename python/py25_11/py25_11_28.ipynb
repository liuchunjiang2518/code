# %%
import pandas as pd
import numpy as np
from pandas import Series
from pandas import DataFrame

# %%
# Out:
#     ID  Rooms  BuyPrice  SellPrice ConstructionTime   TradeTime BuildingType
# 0    1      2   1200000    1350000             2005  2023-05-10          商品房
# 1    2      3   1800000    2000000             2010  2023-06-15          商品房
# 2    3      1    800000     880000             2000  2023-03-22           公寓
# 3    4      2   1100000    1220000               未知  2023-04-05          商品房
# 4    5      3   2500000    2700000             2015  2023-07-18           别墅
# 5    6      2    950000    1050000                0  2023-02-10           公寓
# 6    7      4   3000000    3200000             2018  2023-08-25          商品房
# 7    8      2   1300000    1400000             2008  2023-01-30          商品房
# 8    9      3   1600000    1750000             1999  2023-09-05          老洋房
# 9   10      1    750000     820000                1  2023-05-18           公寓
# 10  11      2   1050000    1180000             2006  2023-06-22          商品房
# ...
